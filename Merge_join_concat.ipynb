# %%
import pandas as pd

# Customer Data
customer = pd.DataFrame({
    "Customer_ID":[1,2,3],
    "Customer_Name":["Amit","Riya","John"]
})

# Sales Data
sales = pd.DataFrame({
    "Customer_ID":[1,2,3],
    "Product_ID":[101,102,103],
    "Amount":[5000,3000,7000]
})

# Product Data
product = pd.DataFrame({
    "Product_ID":[101,102,103],
    "Product_Name":["Laptop","Mobile","Tablet"]
})


# Merge Customer + Sales
customer_sales = pd.merge(customer, sales, on="Customer_ID")

print("Customer Purchase Details")
print(customer_sales)

# Join Product Details
customer_sales.set_index("Product_ID", inplace=True)
product.set_index("Product_ID", inplace=True)

final_data = customer_sales.join(product)

print("\nComplete Sales Report")
print(final_data)

# Monthly Sales Data
jan = pd.DataFrame({
    "Product":["Laptop","Mobile"],
    "Sales":[5000,3000]
})

# Note: Mapping IDs to names to match January's format
feb = pd.DataFrame({
    "Product": ["Laptop","Mobile"], 
    "Sales":[7000,4000]
})

# Combine monthly reports
monthly_report = pd.concat([jan, feb], keys=["January", "February"])

print("\nCombined Monthly Sales Report")
print(monthly_report)
# Out:
# Customer Purchase Details
#    Customer_ID Customer_Name  Product_ID  Amount
# 0            1          Amit         101    5000
# 1            2          Riya         102    3000
# 2            3          John         103    7000
#
# Complete Sales Report
#             Customer_ID Customer_Name  Amount Product_Name
# Product_ID
# 101                   1          Amit    5000       Laptop
# 102                   2          Riya    3000       Mobile
# 103                   3          John    7000       Tablet
#
# Combined Monthly Sales Report
#            Product  Sales
# January  0  Laptop   5000
#          1  Mobile   3000
# February 0  Laptop   7000
#          1  Mobile   4000
