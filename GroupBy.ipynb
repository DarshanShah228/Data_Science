# %%
import pandas as pd

data = {
    "Department": ["Electronics", "Electronics", "Clothing", "Clothing",
                   "Grocery", "Electronics", "Grocery", "Clothing"],
    "City": ["Ahmedabad", "Surat", "Ahmedabad", "Rajkot",
             "Surat", "Rajkot", "Ahmedabad", "Surat"],
    "Branch": ["A", "B", "A", "C",
               "B", "A", "C", "B"],
    "Sales": [50000, 30000, 20000, 25000,
              15000, 45000, 18000, 22000],
    "Profit": [8000, 5000, 3000, 4000,
               2500, 7000, 2800, 3500]
}

df = pd.DataFrame(data)

print("Original Dataset")
print(df)
# Out:
# Original Dataset
#     Department       City Branch  Sales  Profit
# 0  Electronics  Ahmedabad      A  50000    8000
# 1  Electronics      Surat      B  30000    5000
# 2     Clothing  Ahmedabad      A  20000    3000
# 3     Clothing     Rajkot      C  25000    4000
# 4      Grocery      Surat      B  15000    2500
# 5  Electronics     Rajkot      A  45000    7000
# 6      Grocery  Ahmedabad      C  18000    2800
# 7     Clothing      Surat      B  22000    3500

# %%
print("\nDepartment-wise Total Sales")
print(df.groupby("Department")["Sales"].sum())
# Out:
# Department-wise Total Sales
# Department
# Clothing        67000
# Electronics    125000
# Grocery         33000
# Name: Sales, dtype: int64

# %%
print("\nDepartment-wise Average Sales")
print(df.groupby("Department")["Sales"].mean())
# Out:
# Department-wise Average Sales
# Department
# Clothing       22333.333333
# Electronics    41666.666667
# Grocery        16500.000000
# Name: Sales, dtype: float64

# %%
print("\nDepartment-wise Maximum Sales")
print(df.groupby("Department")["Sales"].max())
# Out:
# Department-wise Maximum Sales
# Department
# Clothing       25000
# Electronics    50000
# Grocery        18000
# Name: Sales, dtype: int64

# %%
print("\nDepartment-wise Minimum Sales")
print(df.groupby("Department")["Sales"].min())
# Out:
# Department-wise Minimum Sales
# Department
# Clothing       20000
# Electronics    30000
# Grocery        15000
# Name: Sales, dtype: int64

# %%
print("\nTotal Transactions per Department")
print(df.groupby("Department")["Sales"].count())
# Out:
# Total Transactions per Department
# Department
# Clothing       3
# Electronics    3
# Grocery        2
# Name: Sales, dtype: int64

# %%
print("\nCity-wise Revenue")
print(df.groupby("City")["Sales"].sum())
# Out:
# City-wise Revenue
# City
# Ahmedabad    88000
# Rajkot       70000
# Surat        67000
# Name: Sales, dtype: int64

# %%
print("\nBranch-wise Profit")
print(df.groupby("Branch")["Profit"].sum())
# Out:
# Branch-wise Profit
# Branch
# A    18000
# B    11000
# C     6800
# Name: Profit, dtype: int64

# %%
print("\nDepartment-wise Summary Report")
print(df.groupby("Department")["Sales"].agg(["sum", "mean", "min", "max", "count"]))
# Out:
# Department-wise Summary Report
#                 sum          mean    min    max  count
# Department
# Clothing      67000  22333.333333  20000  25000      3
# Electronics  125000  41666.666667  30000  50000      3
# Grocery       33000  16500.000000  15000  18000      2
